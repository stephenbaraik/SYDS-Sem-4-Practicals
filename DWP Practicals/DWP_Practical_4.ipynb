# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler,StandardScaler,MaxAbsScaler,RobustScaler,Normalizer

# %% [markdown]
# **Normalization is scaling technique in which values are shifted and rescaled ranging between 0 & 1 aka min/Max Scalar**
#
# x' = x - Xmin / Xmax - Xmin
#
# Standardisation is the technique
# when the values are centered around the mean with a unique standard deviation
#
# X' = x - mu/sigma
#
#
# if our data is not normally distributed than we use normalization else we use normal distribution

# %%
df = pd.read_csv(r"https://raw.githubusercontent.com/selva86/datasets/refs/heads/master/BostonHousing.csv")
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
scalar = MinMaxScaler()
# normalize the data 
normalized_data = scalar.fit_transform(df)

# %%
df2 = pd.DataFrame(normalized_data,columns=df.columns)
df2.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.040544    0.113636    0.391378    0.069170    0.349167    0.521869
# std      0.096679    0.233225    0.251479    0.253994    0.238431    0.134627
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000851    0.000000    0.173387    0.000000    0.131687    0.445392
# 50%      0.002812    0.000000    0.338343    0.000000    0.314815    0.507281
# 75%      0.041258    0.125000    0.646628    0.000000    0.491770    0.586798
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.676364    0.242381    0.371713    0.422208    0.622929    0.898568
# ...

# %%
scalar = StandardScaler()
df_scaled = scalar.fit_transform(df)
df3 = pd.DataFrame(df_scaled,columns=df.columns)
df3
# Out:
#          crim        zn     indus      chas       nox        rm       age  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.413672 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.194274  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.282714 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.016303 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.228577 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.439316  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.234548  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.984960  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.725672  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.362767  0.434732
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...

# %%
# mean Normalization
df4 = (df - df.mean())/df.max() - df.min()
df4
# Out:
#          crim        zn     indus     chas       nox        rm       age  \
# 0   -0.046861  0.066364 -0.778197 -0.06917 -0.404168 -3.527929 -2.933749
# 1   -0.046625 -0.113636 -0.606603 -0.06917 -0.483387 -3.545469 -2.796749
# 2   -0.046626 -0.113636 -0.606603 -0.06917 -0.483387 -3.458453 -2.974749
# 3   -0.046568 -0.113636 -0.782883 -0.06917 -0.496016 -3.479751 -3.127749
# 4   -0.046156 -0.113636 -0.782883 -0.06917 -0.496016 -3.462781 -3.043749
# ..        ...       ...       ...      ...       ...       ...       ...
# 501 -0.046228 -0.113636 -0.431405 -0.06917 -0.363984 -3.525879 -2.894749
# 502 -0.046423 -0.113636 -0.431405 -0.06917 -0.363984 -3.579751 -2.818749
# 503 -0.046249 -0.113636 -0.431405 -0.06917 -0.363984 -3.482257 -2.675749
# 504 -0.045701 -0.113636 -0.431405 -0.06917 -0.363984 -3.502986 -2.692749
# 505 -0.046399 -0.113636 -0.431405 -0.06917 -0.363984 -3.590002 -2.777749
#
#           dis       rad         tax    ptratio         b     lstat      medv
# ...

# %%
# maximum absolute scaling
df5 = MaxAbsScaler().fit_transform(df)
df5 = pd.DataFrame(df5,columns=df.columns)
df5
# Out:
#          crim    zn     indus  chas       nox        rm    age       dis  \
# 0    0.000071  0.18  0.083273   0.0  0.617681  0.748861  0.652  0.337278
# 1    0.000307  0.00  0.254867   0.0  0.538462  0.731321  0.789  0.409607
# 2    0.000307  0.00  0.254867   0.0  0.538462  0.818337  0.611  0.409607
# 3    0.000364  0.00  0.078587   0.0  0.525832  0.797039  0.458  0.499913
# 4    0.000776  0.00  0.078587   0.0  0.525832  0.814009  0.542  0.499913
# ..        ...   ...       ...   ...       ...       ...    ...       ...
# 501  0.000704  0.00  0.430065   0.0  0.657865  0.750911  0.691  0.204395
# 502  0.000509  0.00  0.430065   0.0  0.657865  0.697039  0.767  0.188636
# 503  0.000683  0.00  0.430065   0.0  0.657865  0.794533  0.910  0.178741
# 504  0.001232  0.00  0.430065   0.0  0.657865  0.773804  0.893  0.196998
# 505  0.000533  0.00  0.430065   0.0  0.657865  0.686788  0.808  0.206572
#
#           rad       tax   ptratio         b     lstat   medv
# ...

# %%
# median and quantile normalization scaling
# x - median(x) / iqr(x)
df6 = RobustScaler().fit_transform(df)
df6 = pd.DataFrame(df6,columns=df.columns)
df6
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0   -0.069593  1.44 -0.571650   0.0  0.000000  0.496612 -0.250765  0.285777
# 1   -0.063755  0.00 -0.202943   0.0 -0.394286  0.287940  0.028542  0.569789
# 2   -0.063760  0.00 -0.202943   0.0 -0.394286  1.323171 -0.334353  0.569789
# 3   -0.062347  0.00 -0.581720   0.0 -0.457143  1.069783 -0.646279  0.924391
# 4   -0.052144  0.00 -0.581720   0.0 -0.457143  1.271680 -0.475025  0.924391
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 501 -0.053930  0.00  0.173509   0.0  0.200000  0.521003 -0.171254 -0.236007
# 502 -0.058759  0.00  0.173509   0.0  0.200000 -0.119919 -0.016310 -0.297887
# 503 -0.054450  0.00  0.173509   0.0  0.200000  1.039973  0.275229 -0.336744
# 504 -0.040867  0.00  0.173509   0.0  0.200000  0.793360  0.240571 -0.265053
# 505 -0.058164  0.00  0.173509   0.0  0.200000 -0.241870  0.067278 -0.227459
#
# ...

# %%
# L2 regulization is also called as ridge regression it prevents overfitting problem by adding a penalty to the Loss function,
# this penalty discourages large cooeficients in the model.

# vector unit length scaling using L2 normalization 
df7 = Normalizer(norm = 'l2').fit_transform(df)
df7 = pd.DataFrame(df7,columns=df.columns)
df7
# Out:
#          crim        zn     indus  chas       nox        rm       age  \
# 0    0.000013  0.035955  0.004614   0.0  0.001075  0.013134  0.130238
# 1    0.000058  0.000000  0.014961   0.0  0.000992  0.013588  0.166966
# 2    0.000058  0.000000  0.015133   0.0  0.001004  0.015379  0.130778
# 3    0.000071  0.000000  0.004772   0.0  0.001003  0.015319  0.100257
# 4    0.000150  0.000000  0.004740   0.0  0.000996  0.015539  0.117842
# ..        ...       ...       ...   ...       ...       ...       ...
# 501  0.000129  0.000000  0.024652   0.0  0.001184  0.013624  0.142789
# 502  0.000093  0.000000  0.024399   0.0  0.001172  0.012517  0.156866
# 503  0.000124  0.000000  0.024272   0.0  0.001166  0.014193  0.185144
# 504  0.000224  0.000000  0.024430   0.0  0.001173  0.013913  0.182867
# 505  0.000097  0.000000  0.024382   0.0  0.001171  0.012324  0.165133
#
#           dis       rad       tax   ptratio         b     lstat      medv
# ...
